# %% [markdown]
# # Analisis exploratorio datos de Properati
#
# Datos provistos por <a href='http://www.properati.com.ar'>Properati</a>

# %%
propiedades = pd.read_csv('./datos/properati-AR-2014-01-01-properties-sell.csv', low_memory=False)

# %% [markdown]
# ### Analisis de datos

# %%
# magic function para hacer que los graficos de matplotlib se renderizen en el notebook.
# %matplotlib inline

import datetime as datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('default') # haciendo los graficos un poco mas bonitos xD
plt.rcParams['figure.figsize'] = (15, 5)

# %%
propiedades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67750 entries, 0 to 67749
# Data columns (total 20 columns):
# created_on                    67750 non-null object
# operation                     67750 non-null object
# property_type                 67750 non-null object
# place_name                    67750 non-null object
# place_with_parent_names       67750 non-null object
# geonames_id                   57208 non-null float64
# lat-lon                       61984 non-null object
# lat                           61984 non-null float64
# lon                           61981 non-null float64
# price                         55124 non-null float64
# currency                      55124 non-null object
# price_aprox_local_currency    55124 non-null float64
# price_aprox_usd               55124 non-null float64
# surface_in_m2                 54647 non-null float64
# price_usd_per_m2              46384 non-null float64
# floor                         9223 non-null float64
# rooms                         54434 non-null float64
# expenses                      2445 non-null object
# properati_url                 67750 non-null object
# image_thumbnail               63541 non-null object
# dtypes: float64(10), object(10)
# memory usage: 10.3+ MB

# %%
propiedades.describe()
# Out:
#         geonames_id           lat           lon         price  \
# count  5.720800e+04  61984.000000  61981.000000  5.512400e+04
# mean   3.509977e+06    -34.519489    -58.970963  3.102555e+05
# std    3.283422e+05      4.144954      3.838451  4.240839e+05
# min    3.427208e+06    -88.003165   -165.937500  5.300000e+03
# 25%    3.429979e+06    -34.651279    -58.604178  8.900000e+04
# 50%    3.432039e+06    -34.600314    -58.474217  1.500000e+05
# 75%    3.435874e+06    -34.543651    -58.397465  3.771000e+05
# max    6.948895e+06     50.451911    174.375000  1.380000e+07
#
#        price_aprox_local_currency  price_aprox_usd  surface_in_m2  \
# count                5.512400e+04     5.512400e+04   54647.000000
# mean                 1.183504e+06     1.842459e+05     139.866580
# std                  1.528592e+06     2.379687e+05     296.832978
# min                  3.299996e+04     5.137380e+03      20.000000
# 25%                  5.200000e+05     8.095275e+04      46.000000
# 50%                  7.708200e+05     1.200000e+05      74.000000
# 75%                  1.284700e+06     2.000000e+05     145.000000
# max                  8.864430e+07     1.380000e+07   10000.000000
#
#        price_usd_per_m2        floor         rooms
# count      46384.000000  9223.000000  54434.000000
# mean        2033.335121    14.134338      2.476393
# std         1695.858984    99.709670      1.278816
# min            0.000500     0.000000      0.000000
# 25%         1296.691175     2.000000      2.000000
# 50%         1839.031755     4.000000      2.000000
# 75%         2444.444444     7.000000      3.000000
# max       120000.000000  5055.000000     39.000000

# %%
propiedades.head(5)
# Out:
#    created_on operation property_type          place_name  \
# 0  2012-08-08      sell     apartment            Belgrano
# 1  2012-08-08      sell     apartment     Villa Ballester
# 2  2012-08-08      sell         house     Villa Ballester
# 3  2012-08-08      sell         house     Villa Ballester
# 4  2012-08-08      sell     apartment  General San Martín
#
#                              place_with_parent_names  geonames_id  \
# 0               |Argentina|Capital Federal|Belgrano|    3436077.0
# 1  |Argentina|Bs.As. G.B.A. Zona Norte|General Sa...    3427467.0
# 2  |Argentina|Bs.As. G.B.A. Zona Norte|General Sa...    3427467.0
# 3  |Argentina|Bs.As. G.B.A. Zona Norte|General Sa...    3427467.0
# 4  |Argentina|Bs.As. G.B.A. Zona Norte|General Sa...    3433778.0
#
#                  lat-lon        lat        lon     price currency  \
# 0  -34.561208,-58.464514 -34.561208 -58.464514       NaN      NaN
# 1   -34.54673,-58.550579 -34.546730 -58.550579       NaN      NaN
# 2  -34.543776,-58.559615 -34.543776 -58.559615       NaN      NaN
# 3                    NaN        NaN        NaN  110000.0      USD
# 4  -34.622794,-58.577988 -34.622794 -58.577988       NaN      NaN
#
#    price_aprox_local_currency  price_aprox_usd  surface_in_m2  \
# 0                         NaN              NaN          102.0
# 1                         NaN              NaN           73.0
# 2                         NaN              NaN          485.0
# 3                    706585.0         110000.0          349.0
# 4                         NaN              NaN            NaN
#
#    price_usd_per_m2  floor  rooms   expenses  \
# 0               NaN   10.0    3.0  850 aprox
# 1               NaN   11.0    3.0        NaN
# 2               NaN    NaN    4.0        NaN
# 3        315.186246    NaN    4.0        NaN
# 4               NaN    NaN    3.0        NaN
#
#                                        properati_url  \
# 0  http://www.properati.com.ar/ag_venta_departame...
# 1  http://www.properati.com.ar/ah_venta_departame...
# 2  http://www.properati.com.ar/aj_venta_casa_vill...
# 3  http://www.properati.com.ar/ak_venta_casa_vill...
# 4  http://www.properati.com.ar/ao_venta_departame...
#
#                                      image_thumbnail
# 0  http://cf-thumbs.properati.com.ar/Cry7pVKa41t_...
# 1  http://cf-thumbs.properati.com.ar/MwrzW_dkQbqR...
# 2  http://cf-thumbs.properati.com.ar/2wMqxAsh1N2t...
# 3  http://cf-thumbs.properati.com.ar/uMwzJsvexa1C...
# 4  http://cf-thumbs.properati.com.ar/4kPnofvgR6hs...

# %% [markdown]
# ### ¿Cuales son los barrios que tienen las propiedades mas caras a la venta por metro cuadrado?

# %%
propiedades.groupby(['place_with_parent_names']).mean().sort_values(['price_usd_per_m2'],ascending=False).head(5)
# Out:
#                                            geonames_id        lat        lon  \
# place_with_parent_names
# |Argentina|Tierra Del Fuego|Río Grande|      3838854.0 -54.171504 -67.950277
# |Argentina|Capital Federal|Puerto Madero|    3429760.0 -34.612313 -58.363245
# |Argentina|Buenos Aires Interior|Campana|    3435809.0 -31.078860 -61.131942
# |Argentina|Entre Ríos|Costa Uruguay Sur|           NaN -32.805806 -58.119466
# |Argentina|Capital Federal|Las Cañitas|            NaN -31.987083 -59.929430
#
#                                                   price  \
# place_with_parent_names
# |Argentina|Tierra Del Fuego|Río Grande|    3.340000e+06
# |Argentina|Capital Federal|Puerto Madero|  7.152989e+05
# |Argentina|Buenos Aires Interior|Campana|  3.467500e+05
# |Argentina|Entre Ríos|Costa Uruguay Sur|   4.700321e+05
# |Argentina|Capital Federal|Las Cañitas|    2.789111e+05
#
#                                            price_aprox_local_currency  \
# place_with_parent_names
# |Argentina|Tierra Del Fuego|Río Grande|                  1.116069e+07
# |Argentina|Capital Federal|Puerto Madero|                4.186055e+06
# |Argentina|Buenos Aires Interior|Campana|                1.386706e+06
# |Argentina|Entre Ríos|Costa Uruguay Sur|                 2.990965e+06
# |Argentina|Capital Federal|Las Cañitas|                  1.657016e+06
#
#                                            price_aprox_usd  surface_in_m2  \
# place_with_parent_names
# |Argentina|Tierra Del Fuego|Río Grande|       1.737478e+06     116.333333
# |Argentina|Capital Federal|Puerto Madero|     6.516783e+05     139.242991
# |Argentina|Buenos Aires Interior|Campana|     2.158801e+05     148.263158
# |Argentina|Entre Ríos|Costa Uruguay Sur|      4.656286e+05     145.386100
# |Argentina|Capital Federal|Las Cañitas|       2.579616e+05      91.394231
#
#                                            price_usd_per_m2      floor  \
# place_with_parent_names
# |Argentina|Tierra Del Fuego|Río Grande|        17350.251698        NaN
# |Argentina|Capital Federal|Puerto Madero|       4893.387687  14.785714
# |Argentina|Buenos Aires Interior|Campana|       3514.659928        NaN
# |Argentina|Entre Ríos|Costa Uruguay Sur|        3458.517234   6.142857
# |Argentina|Capital Federal|Las Cañitas|         3325.399109   7.225000
#
#                                               rooms
# place_with_parent_names
# |Argentina|Tierra Del Fuego|Río Grande|    2.166667
# |Argentina|Capital Federal|Puerto Madero|  2.704036
# |Argentina|Buenos Aires Interior|Campana|  2.750000
# |Argentina|Entre Ríos|Costa Uruguay Sur|   2.857664
# |Argentina|Capital Federal|Las Cañitas|    2.452756

# %% [markdown]
# ### ¿Cuales son los barrios donde se venden mas propiedades?

# %%
propiedades.groupby('place_with_parent_names').size().sort_values(ascending=False).head(10)
# Out:
# place_with_parent_names
# |Argentina|Buenos Aires Costa Atlántica|Mar del Plata|    5879
# |Argentina|Capital Federal|                               4281
# |Argentina|Capital Federal|Belgrano|                      2131
# |Argentina|Santa Fe|Rosario|                              2003
# |Argentina|Bs.As. G.B.A. Zona Norte|Pilar|                1813
# |Argentina|Capital Federal|Palermo|Palermo Chico|         1624
# |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|                1549
# |Argentina|Capital Federal|Barrio Norte|                  1245
# |Argentina|Capital Federal|Villa Urquiza|                 1228
# |Argentina|Capital Federal|Caballito|                     1200
# dtype: int64

# %% [markdown]
# ### ¿Cuales son los barrios donde se venden mas casas?

# %%
propiedades[propiedades["property_type"]=="house"].groupby('place_with_parent_names').size().sort_values(ascending=False).head(10)
# Out:
# place_with_parent_names
# |Argentina|Bs.As. G.B.A. Zona Norte|Pilar|                               1208
# |Argentina|Capital Federal|                                               800
# |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|                                751
# |Argentina|Bs.As. G.B.A. Zona Oeste|Moreno|                               509
# |Argentina|Bs.As. G.B.A. Zona Oeste|Ituzaingó|Ituzaingó|                  499
# |Argentina|Buenos Aires Costa Atlántica|Mar del Plata|                    496
# |Argentina|Santa Fe|Santa Fe|                                             399
# |Argentina|Santa Fe|Rosario|                                              334
# |Argentina|Bs.As. G.B.A. Zona Oeste|Morón|Castelar|                       321
# |Argentina|Río Negro|San Carlos de Bariloche|San Carlos de Bariloche|     306
# dtype: int64
